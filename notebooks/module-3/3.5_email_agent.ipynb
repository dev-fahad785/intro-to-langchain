# %% [markdown]
# email agent
# - authenticates user
#     - only then are they allowed into the "inbox"
#     - dynamic tools and prompt on the condition of there being an email and password in state that match hardcoded
# - checks "inbox"
#     - email in tool
# - sends emails
#     - human in the loop

# %%
import warnings
warnings.filterwarnings("ignore", message=".*Pydantic serializer warnings.*", category=UserWarning)

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from dataclasses import dataclass

@dataclass
class EmailContext:
    email_address: str = "julie@example.com"
    password: str = "password123"

# %%
from langchain.agents import AgentState

class AuthenticatedState(AgentState):
    authenticated: bool

# %%
from langchain.tools import tool, ToolRuntime
from langgraph.types import Command
from langchain.messages import ToolMessage

@tool
def check_inbox() -> str:
    """Check the inbox for recent emails"""
    return """
    Hi Julie, 
    I'm going to be in town next week and was wondering if we could grab a coffee?
    - best, Jane (jane@example.com)
    """

@tool
def send_email(to: str, subject: str, body: str) -> str:
    """Send an response email"""
    return f"Email sent to {to} with subject {subject} and body {body}"

@tool
def authenticate(email: str, password: str, runtime: ToolRuntime) -> Command:
    """Authenticate the user with the given email and password"""
    if email == runtime.context.email_address and password == runtime.context.password:
        return Command(update={
            "authenticated": True, 
            "messages": [ToolMessage(
                "Successfully authenticated", 
                tool_call_id=runtime.tool_call_id)]
        })
    else:
        return Command(update={
            "authenticated": False,
            "messages": [ToolMessage(
                "Authentication failed", 
                tool_call_id=runtime.tool_call_id)]
        })

# %%
from langchain.agents.middleware import wrap_model_call, ModelRequest, ModelResponse
from typing import Callable

@wrap_model_call
def dynamic_tool_call(request: ModelRequest, 
handler: Callable[[ModelRequest], ModelResponse]) -> ModelResponse:

    """Allow read inbox and send email tools only if user provides correct email and password"""

    authenticated = request.state.get("authenticated")
    
    if authenticated:
        tools = [check_inbox, send_email]
    else:
        tools = [authenticate]

    request = request.override(tools=tools) 
    return handler(request)

# %% [markdown]
# >Note: the prompts were modified since filming to constrain the model to more reliably match the filmed sequence. You may still experience different responses from the model, which is expected. You may need to modify the human message to provide appropriate responses.

# %%
from langchain.agents.middleware import dynamic_prompt

authenticated_prompt = """You are a helpful assistant that can check the inbox and send emails. 
Your first step after authentication is to check the inbox."""
unauthenticated_prompt = "You are a helpful assistant that can authenticate users."

@dynamic_prompt
def dynamic_prompt(request: ModelRequest) -> str:
    """Generate system prompt based on authentication status"""
    authenticated = request.state.get("authenticated")

    if authenticated:
        return authenticated_prompt
    else:
        return unauthenticated_prompt

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver
from langchain.agents.middleware import HumanInTheLoopMiddleware

agent = create_agent(
    "google_genai:gemini-3.1-flash-lite",
    tools=[authenticate, check_inbox, send_email],
    checkpointer=InMemorySaver(),
    state_schema=AuthenticatedState,
    context_schema=EmailContext,
    middleware=[
        dynamic_tool_call, 
        dynamic_prompt,
        HumanInTheLoopMiddleware(
            interrupt_on={
                "authenticate": False,
                "check_inbox": False,
                "send_email": True,
            })
        ]
    )

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [HumanMessage(content="julie@example.com, password123")]},
    context=EmailContext(),
    config=config
)

print(response['messages'][-1].content)
# Out:
# ---------------------------------------------------------------------------
# ConnectTimeout                            Traceback (most recent call last)
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/httpcore/_sync/connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/httpcore/_sync/connection.py:156, in HTTPConnection._connect(self, request)
#     155 with Trace("start_tls", logger, request, kwargs) as trace:
# --> 156     stream = stream.start_tls(**kwargs)
#     157     trace.return_value = stream
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/httpcore/_backends/sync.py:154, in SyncStream.start_tls(self, ssl_context, server_hostname, timeout)
#     150 exc_map: ExceptionMapping = {
#     151     socket.timeout: ConnectTimeout,
#     152     OSError: ConnectError,
#     153 }
# --> 154 with map_exceptions(exc_map):
#     155     try:
#
# File ~/.local/share/uv/python/cpython-3.13.14-linux-x86_64-gnu/lib/python3.13/contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectTimeout: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# ConnectTimeout                            Traceback (most recent call last)
# Cell In[8], line 5
#       1 from langchain.messages import HumanMessage
#       3 config = {"configurable": {"thread_id": "1"}}
# ----> 5 response = agent.invoke(
#       6     {"messages": [HumanMessage(content="julie@example.com, password123")]},
#       7     context=EmailContext(),
#       8     config=config
#       9 )
#      11 print(response['messages'][-1].content)
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/pregel/main.py:3928, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3925             chunks.append(chunk)
#    3926 else:
#    3927     # v1: collect interrupts from updates stream
# -> 3928     for chunk in self.stream(
#    3929         input,
#    3930         config,
#    3931         context=context,
#    3932         stream_mode=(
#    3933             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3934         ),
#    3935         print_mode=print_mode,
#    3936         output_keys=output_keys,
#    3937         interrupt_before=interrupt_before,
#    3938         interrupt_after=interrupt_after,
#    3939         durability=durability,
#    3940         control=control,
#    3941         **kwargs,
#    3942     ):
#    3943         if stream_mode == "values":
#    3944             if len(chunk) == 2:
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/pregel/main.py:2982, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2980 for task in loop.match_cached_writes():
#    2981     loop.output_writes(task.id, task.writes, cached=True)
# -> 2982 for _ in runner.tick(
#    2983     [t for t in loop.tasks.values() if not t.writes],
#    2984     timeout=self.step_timeout,
#    2985     get_waiter=get_waiter,
#    2986     schedule_task=loop.accept_push,
#    2987 ):
#    2988     # emit output
#    2989     yield from _output(
#    2990         stream_mode,
#    2991         print_mode,
#    (...)   2997         _state_mapper,
#    2998     )
#    2999 loop.after_tick()
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/pregel/_runner.py:207, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     205 scheduled_error_handler = False
#     206 try:
# --> 207     run_with_retry(
#     208         t,
#     209         retry_policy,
#     210         configurable={
#     211             CONFIG_KEY_CALL: partial(
#     212                 _call,
#     213                 weakref.ref(t),
#     214                 retry_policy=retry_policy,
#     215                 futures=weakref.ref(futures),
#     216                 schedule_task=schedule_task,
#     217                 submit=self.submit,
#     218             ),
#     219         },
#     220     )
#     221     self.commit(t, None)
#     222 except Exception as exc:
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/pregel/_retry.py:617, in run_with_retry(task, retry_policy, configurable)
#     615     task.writes.clear()
#     616     # run the task
# --> 617     return task.proc.invoke(task.input, config)
#     618 except ParentCommand as exc:
#     619     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/_internal/_runnable.py:684, in RunnableSeq.invoke(self, input, config, **kwargs)
#     682     # run in context
#     683     with set_config_context(config, run) as context:
# --> 684         input = context.run(step.invoke, input, config, **kwargs)
#     685 else:
#     686     input = step.invoke(input, config)
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/_internal/_runnable.py:426, in RunnableCallable.invoke(self, input, config, **kwargs)
#     424         run_manager.on_chain_end(ret)
#     425 else:
# --> 426     ret = self.func(*args, **kwargs)
#     427 if self.recurse and isinstance(ret, Runnable):
#     428     return ret.invoke(input, config)
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain/agents/factory.py:1424, in create_agent.<locals>.model_node(state, runtime)
#    1421     model_response = _execute_model_sync(request)
#    1422     return _build_commands(model_response)
# -> 1424 result = wrap_model_call_handler(request, _execute_model_sync)
#    1425 return _build_commands(result.model_response, result.commands)
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain/agents/factory.py:310, in _chain_model_call_handlers.<locals>.compose_two.<locals>.composed(request, handler)
#     307         return inner_result.model_response
#     308     return _normalize_to_model_response(inner_result)
# --> 310 outer_result = outer(request, inner_handler)
#     311 return _to_composed_result(
#     312     outer_result,
#     313     extra_commands=accumulated_commands or None,
#     314 )
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain/agents/middleware/types.py:1968, in wrap_model_call.<locals>.decorator.<locals>.wrapped(_self, request, handler)
#    1963 def wrapped(
#    1964     _self: AgentMiddleware[StateT, ContextT],
#    1965     request: ModelRequest[ContextT],
#    1966     handler: Callable[[ModelRequest[ContextT]], ModelResponse[ResponseT]],
#    1967 ) -> ModelCallResult[ResponseT]:
# -> 1968     return cast("_SyncCallableReturningModelResponse[ContextT, ResponseT]", func)(
#    1969         request, handler
#    1970     )
#
# Cell In[5], line 18, in dynamic_tool_call(request, handler)
#      15     tools = [authenticate]
#      17 request = request.override(tools=tools)
# ---> 18 return handler(request)
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain/agents/factory.py:300, in _chain_model_call_handlers.<locals>.compose_two.<locals>.composed.<locals>.inner_handler(req)
#     297 def inner_handler(req: ModelRequest[ContextT]) -> ModelResponse:
#     298     # Clear on each call for retry safety
#     299     accumulated_commands.clear()
# --> 300     inner_result = inner(req, handler)
#     301     if isinstance(inner_result, _ComposedExtendedModelResponse):
#     302         accumulated_commands.extend(inner_result.commands)
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain/agents/middleware/types.py:1783, in dynamic_prompt.<locals>.decorator.<locals>.wrapped(_self, request, handler)
#    1781 else:
#    1782     request = request.override(system_message=SystemMessage(content=prompt))
# -> 1783 return handler(request)
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain/agents/factory.py:1393, in create_agent.<locals>._execute_model_sync(request)
#    1390 if request.system_message:
#    1391     messages = [request.system_message, *messages]
# -> 1393 output = model_.invoke(messages)
#    1394 if name:
#    1395     output.name = name
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/runnables/base.py:6004, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5997 @override
#    5998 def invoke(
#    5999     self,
#    (...)   6002     **kwargs: Any | None,
#    6003 ) -> Output:
# -> 6004     return self.bound.invoke(
#    6005         input,
#    6006         self._merge_configs(config),
#    6007         **{**self.kwargs, **kwargs},
#    6008     )
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_google_genai/chat_models.py:2535, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2532         msg = "Tools are already defined.code_execution tool can't be defined"
#    2533         raise ValueError(msg)
# -> 2535 return super().invoke(input, config, stop=stop, **kwargs)
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_google_genai/chat_models.py:3047, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3034 request = self._prepare_request(
#    3035     messages,
#    3036     stop=stop,
#    (...)   3044     **kwargs,
#    3045 )
#    3046 try:
# -> 3047     response: GenerateContentResponse = self.client.models.generate_content(
#    3048         **request,
#    3049     )
#    3050 except ClientError as e:
#    3051     _handle_client_error(e, request)
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/google/genai/models.py:5694, in Models.generate_content(self, model, contents, config)
#    5686     indices_str = ', '.join(map(str, incompatible_tools_indexes))
#    5687     logger.warning(
#    5688         'Tools at indices [%s] are not compatible with automatic function '
#    5689         'calling (AFC). AFC is disabled. If AFC is intended, please '
#    (...)   5692         indices_str,
#    5693     )
# -> 5694   return self._generate_content(
#    5695       model=model, contents=contents, config=parsed_config
#    5696   )
#    5698 remaining_remote_calls_afc = _extra_utils.get_max_remote_calls_afc(
#    5699     parsed_config
#    5700 )
#    5701 logger.info(
#    5702     f'AFC is enabled with max remote calls: {remaining_remote_calls_afc}.'
#    5703 )
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/google/genai/models.py:4371, in Models._generate_content(self, model, contents, config)
#    4368 request_dict = _common.convert_to_dict(request_dict)
#    4369 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4371 response = self._api_client.request(
#    4372     'post', path, request_dict, http_options
#    4373 )
#    4375 if config is not None and getattr(
#    4376     config, 'should_return_http_response', None
#    4377 ):
#    4378   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/google/genai/_api_client.py:1401, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1391 def request(
#    1392     self,
#    1393     http_method: str,
#    (...)   1396     http_options: Optional[HttpOptionsOrDict] = None,
#    1397 ) -> SdkHttpResponse:
#    1398   http_request = self._build_request(
#    1399       http_method, path, request_dict, http_options
#    1400   )
# -> 1401   response = self._request(http_request, http_options, stream=False)
#    1402   response_body = (
#    1403       response.response_stream[0] if response.response_stream else ''
#    1404   )
#    1405   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/google/genai/_api_client.py:1235, in BaseApiClient._request(self, http_request, http_options, stream)
#    1233     retry_kwargs = retry_args(parameter_model.retry_options)
#    1234     retry = tenacity.Retrying(**retry_kwargs)
# -> 1235     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1237 return self._retry(self._request_once, http_request, stream)
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/tenacity/__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/tenacity/__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/tenacity/__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     391 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     392     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393         self._add_action_func(lambda rs: rs.outcome.result())
#     394         return
#     396     if self.after is not None:
#
# File ~/.local/share/uv/python/cpython-3.13.14-linux-x86_64-gnu/lib/python3.13/concurrent/futures/_base.py:453, in Future.result(self, timeout)
#     451     raise CancelledError()
#     452 elif self._state == FINISHED:
# --> 453     return self.__get_result()
#     455 self._condition.wait(timeout)
#     457 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/.local/share/uv/python/cpython-3.13.14-linux-x86_64-gnu/lib/python3.13/concurrent/futures/_base.py:402, in Future.__get_result(self)
#     400 if self._exception is not None:
#     401     try:
# --> 402         raise self._exception
#     403     finally:
#     404         # Break a reference cycle with the exception in self._exception
#     405         self = None
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/tenacity/__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/google/genai/_api_client.py:1207, in BaseApiClient._request_once(self, http_request, stream)
#    1203   return HttpResponse(
#    1204       response.headers, response if stream else [response.text]
#    1205   )
#    1206 else:
# -> 1207   response = self._httpx_client.request(
#    1208       method=http_request.method,
#    1209       url=http_request.url,
#    1210       headers=http_request.headers,
#    1211       content=data,
#    1212       timeout=http_request.timeout,
#    1213   )
#    1214   errors.APIError.raise_for_response(response)
#    1215   return HttpResponse(
#    1216       response.headers, response if stream else [response.text]
#    1217   )
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/httpx/_transports/default.py:249, in HTTPTransport.handle_request(self, request)
#     235 import httpcore
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/.local/share/uv/python/cpython-3.13.14-linux-x86_64-gnu/lib/python3.13/contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     160     value = typ()
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#     167     return exc is not value
#
# File ~/Desktop/New Folder/study/self-learning/ai-agents/lca-lc-foundations/.venv/lib/python3.13/site-packages/httpx/_transports/default.py:118, in map_httpcore_exceptions()
#     115     raise
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectTimeout: [Errno 110] Connection timed out
# During task with name 'model' and id 'df8d172f-4e4b-9c10-8f85-90fa7145095e'

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="any draft is fine. don't check back.")]},
    context=EmailContext(),
    config=config
)

print(response['messages'][-1].content)

# %%
print(response['__interrupt__'][0].value['action_requests'][0]['args']['body'])
# Out:
# Hi Jane,
# That sounds great! I’d love to. I’m free Tuesday or Thursday afternoon next week. Do either work for you? If you have a preferred cafe, let me know.
# Looking forward to it!

# %%
from langgraph.types import Command

response = agent.invoke(
    Command( 
        resume={"decisions": [{"type": "approve"}]}  # or "reject"
    ), 
    config=config # Same thread ID to resume the paused conversation
)

print(response["messages"][-1].content)
# Out:
# Email sent to jane@example.com with subject "Re: Coffee next week" and body:
# Hi Jane,
# That sounds great! I’d love to. I’m free Tuesday or Thursday afternoon next week. Do either work for you? If you have a preferred cafe, let me know.
# Looking forward to it!

# %%
from pprint import pprint

pprint(response)
# Out:
# {'authenticated': True,
#  'messages': [HumanMessage(content='julie@example.com, password123', additional_kwargs={}, response_metadata={}, id='cd6784ff-58d9-400d-bb0e-3da84fc0dc46'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 286, 'prompt_tokens': 151, 'total_tokens': 437, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DOoSKZcepxV1pNVbCpkTQRJqWnZzV', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d3ab1-5dbd-7223-9e59-5edf45a39d77-0', tool_calls=[{'name': 'authenticate', 'args': {'email': 'julie@example.com', 'password': 'password123'}, 'id': 'call_nGaIRLsjvsIr8BHfSN4dxN0k', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 151, 'output_tokens': 286, 'total_tokens': 437, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}}),
#               ToolMessage(content='Successfully authenticated', name='authenticate', id='b1d708d2-332a-4403-ad02-eb8b6a43d858', tool_call_id='call_nGaIRLsjvsIr8BHfSN4dxN0k'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 84, 'prompt_tokens': 219, 'total_tokens': 303, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DOoSNqA3ULOidJqDO24CFIDTdtF6e', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d3ab1-6da9-7a22-b448-fb38d52f717a-0', tool_calls=[{'name': 'check_inbox', 'args': {}, 'id': 'call_pAtYj0tr0cT4CIer9EFNIs1V', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 219, 'output_tokens': 84, 'total_tokens': 303, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}),
#               ToolMessage(content="\n    Hi Julie, \n    I'm going to be in town next week and was wondering if we could grab a coffee?\n    - best, Jane (jane@example.com)\n    ", name='check_inbox', id='3bc891dd-b682-4a85-ba98-140137f26754', tool_call_id='call_pAtYj0tr0cT4CIer9EFNIs1V'),
#               AIMessage(content="I checked your inbox. Here’s the message I found:\n\nFrom: Jane (jane@example.com)\nSubject: (not shown)\nHello Julie,\nHi Julie, I'm going to be in town next week and was wondering if we could grab a coffee?\n- best, Jane\n\nWould you like me to reply and suggest a few times? Here are a few draft options you can choose from (or I can tailor them to your style):\n\nOption 1 — casual and friendly\nSubject: Re: Coffee next week\nHi Jane,\nThat sounds great! I’d love to. I’m free Tuesday or Thursday afternoon next week. Do either work for you? If you have a preferred cafe, let me know.\nLooking forward to it!\n\nOption 2 — specific times\nSubject: Re: Coffee next week\nHi Jane,\nI’d love to meet up. How about Tuesday at 3:00 PM or Thursday at 11:00 AM? If neither works, I’m happy to adapt. Let me know what’s convenient.\n\nOption 3 — location suggestion\nSubject: Re: Coffee next week\nHi Jane,\nI’d love to catch up. Want to meet at [Cafe Name] next week? I’m free Tue and Thu afternoon. What works for you?\n\nIf you have a preferred tone or a preferred cafe, tell me and I’ll tailor the draft. Once you pick a draft, I can send the email for you.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1068, 'prompt_tokens': 282, 'total_tokens': 1350, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DOoSQvNgP3k0W1deRzpms7cEsF2i3', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d3ab1-771e-7741-bace-bf043afec052-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 282, 'output_tokens': 1068, 'total_tokens': 1350, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}}),
#               HumanMessage(content="any draft is fine. don't check back.", additional_kwargs={}, response_metadata={}, id='3aab7bfc-46e1-4bd7-9724-cdceac30272c'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 595, 'prompt_tokens': 592, 'total_tokens': 1187, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DOoSdXb69hI0RspjP91GgPqKeluj0', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d3ab1-a92d-7fa0-aa51-ca0841aad97f-0', tool_calls=[{'name': 'send_email', 'args': {'to': 'jane@example.com', 'subject': 'Re: Coffee next week', 'body': 'Hi Jane,\nThat sounds great! I’d love to. I’m free Tuesday or Thursday afternoon next week. Do either work for you? If you have a preferred cafe, let me know.\nLooking forward to it!'}, 'id': 'call_Z3176PTpfLJaAAZAFngWEqKJ', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 592, 'output_tokens': 595, 'total_tokens': 1187, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}}),
#               ToolMessage(content='Email sent to jane@example.com with subject Re: Coffee next week and body Hi Jane,\nThat sounds great! I’d love to. I’m free Tuesday or Thursday afternoon next week. Do either work for you? If you have a preferred cafe, let me know.\nLooking forward to it!', name='send_email', id='5da47fd6-a274-40d3-8165-5bebeb38dd8b', tool_call_id='call_Z3176PTpfLJaAAZAFngWEqKJ'),
#               AIMessage(content='Email sent to jane@example.com with subject "Re: Coffee next week" and body:\nHi Jane,\nThat sounds great! I’d love to. I’m free Tuesday or Thursday afternoon next week. Do either work for you? If you have a preferred cafe, let me know.\nLooking forward to it!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 65, 'prompt_tokens': 739, 'total_tokens': 804, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DOoSlLB1fh1ysL4fRM9H7zHrKpuOO', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d3ab1-c937-7e91-bfb1-0b41d10a03f6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 739, 'output_tokens': 65, 'total_tokens': 804, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
