# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from dataclasses import dataclass
from langchain.agents.middleware import dynamic_prompt, ModelRequest

@dataclass
class LanguageContext:
    user_language: str = "English"

@dynamic_prompt
def user_language_prompt(request: ModelRequest) -> str:
    """Generate system prompt based on user role."""
    user_language = request.runtime.context.user_language
    base_prompt = "You are a helpful assistant."

    if user_language != "English":
        return f"{base_prompt} only respond in {user_language}."
    elif user_language == "English":
        return base_prompt

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="google_genai:gemini-3.1-flash-lite",
    context_schema=LanguageContext,
    middleware=[user_language_prompt]
)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="Hello, how are you?")]},
    context=LanguageContext(user_language="Irish")
)

print(response["messages"][-1].content)
# Out:
# [{'type': 'text', 'text': 'Dia duit! Táim go maith, go raibh maith agat. Conas atá tú féin?', 'extras': {'signature': 'EjQKMgERTTIP/7K0ODMdv1QXVLIIinL+ggpnfkg6TIt7yIREj8BXp6tCafF70K0MypbhSS5h'}}]

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="Hello, how are you?")]},
    context=LanguageContext(user_language="hinglish")
)

print(response["messages"][-1].content)
# Out:
# [{'type': 'text', 'text': 'Hello! Main bilkul thik hoon, shukriya. Aap kaise hain? Main aapki kya madad kar sakta hoon?', 'extras': {'signature': 'EjQKMgERTTIPmE0jRjJ1LwXeLAa0d/Qpym6D4btEHqvfjhfMlEScwmYLwgqclploena4rw9w'}}]

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="Hello, how are you?")]},
    context=LanguageContext(user_language="French")
)

print(response["messages"][-1].content)
# Out:
# [{'type': 'text', 'text': "Bonjour ! Je vais très bien, merci. Et vous, comment allez-vous aujourd'hui ?", 'extras': {'signature': 'EjQKMgERTTIPSq6sip2RVdhPNIdsukJa0pw4MROvN9niq3e7gBujeS5i1pSUWjAawTghNQaR'}}]
